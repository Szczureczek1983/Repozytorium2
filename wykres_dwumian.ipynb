# %% [markdown]
# <a href="https://colab.research.google.com/github/Szczureczek1983/Repozytorium2/blob/main/wykres_dwumian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importujemy biblioteki
import numpy as np
import pylab
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 100 # poprawia jakość wykresu
# podajemy parametry a,b i c
a = float(input("Podaj współczynnik a: "))
b = float(input("Podaj współczynnik b: "))
c = float(input("Podaj współczynnik c: "))
X = pylab.arange(-10,11,1) 
fx = []
for i in X:
  fx = a*X**2+b*X+2*c
# kreślimy wykres
plt.plot(X,fx, "-o", color="r")
plt.xlabel("Wartości X")
plt.ylabel("Wartości funkcji fx")
plt.title('Wykres funkcji fx = a*X$^{2}$+b*X+2*c')
plt.grid(True)
plt.show()
# Out:
# Podaj współczynnik a: -12
# Podaj współczynnik b: 2
# Podaj współczynnik c: 34
